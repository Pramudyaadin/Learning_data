# %% [markdown]
# # Graded Challenge 1
#
# - Nama  = Pramudya Adi Nugraha
# - Batch = 10

# %% [markdown]
# ## Description
#
# ### Objective
#
# Graded Challenge 1 ini dibuat guna mengevaluasi konsep Basic Python, Numpy, serta Data Preparation with Pandas sebagai berikut:
#
# - Mampu memuat data dengan Pandas
# - Mampu menangani missing values pada dataset
# - Mampu melakukan manipulasi kolom
# - Mampu membuat query terhadap dataset
# - Mampu melakukan grouping terhadap dataset
# - Mampu melakukan visualisasi sederhana menggunakan Pandas
#
# ### Problem Statement
#
# - proses data loading yang kemudian dilanjutkan dengan explorasi data secara sederhana.
# - proses penyiapan data berupa data cleaning sebelum dilakukan explorasi data lebih lanjut. Proses cleaning dapat berupa memberi nama baru untuk setiap kolom, mengisi missing values, menghapus kolom yang tidak dipakai, dan lain sebagainya.
# - explorasi data pada dataset diatas dengan menggunakan query, grouping, visualisasi sederhana, dan lain sebagainya.

# %% [markdown]
# ## Working Area

# %% [markdown]
# ### Import Pustaka

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Data Loading

# %%
data_pokemon = pd.read_csv('Pokemon.csv')
data_pokemon
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
data_pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
data_pokemon['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
data_pokemon['Type 1'].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
data_pokemon['Type 2'].value_counts().sum()
# Out:
# 414

# %% [markdown]
# ### Data Cleaning

# %%
data_new = data_pokemon.dropna()
data_new
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 6      6              Charizard     Fire  Flying    534  78      84       78
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
data_new.rename(columns= {'#' : 'Number', 'Type 1' : 'Type_1', 'Type 2' : 'Type_2', 'Sp. Atk' : 'Sp_Atk', 'Sp. Def' : 'Sp_Deff'}, inplace= True)
# Out:
# C:\Users\Pramudya\anaconda3\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
data_new
# Out:
#      Number                   Name   Type_1  Type_2  Total  HP  Attack  \
# 0         1              Bulbasaur    Grass  Poison    318  45      49
# 1         2                Ivysaur    Grass  Poison    405  60      62
# 2         3               Venusaur    Grass  Poison    525  80      82
# 3         3  VenusaurMega Venusaur    Grass  Poison    625  80     100
# 6         6              Charizard     Fire  Flying    534  78      84
# ..      ...                    ...      ...     ...    ...  ..     ...
# 795     719                Diancie     Rock   Fairy    600  50     100
# 796     719    DiancieMega Diancie     Rock   Fairy    700  50     160
# 797     720    HoopaHoopa Confined  Psychic   Ghost    600  80     110
# 798     720     HoopaHoopa Unbound  Psychic    Dark    680  80     160
# 799     721              Volcanion     Fire   Water    600  80     110
#
#      Defense  Sp_Atk  Sp_Deff  Speed  Generation  Legendary
# ...

# %% [markdown]
# ### Explorasi Data

# %% [markdown]
# #### Query Data

# %%
# mengambil data pokemon dengan 2 Type, tetapi Type1 Water
# memiliki Total lebih besar dari 500
# generation lebih dari 3
# data yang ditampilkan hanya number, name, type1, type2, total, dan generasi

data_new.query("Type_1 == 'Water' & Total >= 500 & Generation > 3 ")[[
    'Number', 'Name', 'Type_1', 'Type_2', 'Total', 'Generation']]
# Out:
#      Number                  Name Type_1    Type_2  Total  Generation
# 440     395              Empoleon  Water     Steel    530           4
# 541     484                Palkia  Water    Dragon    680           4
# 597     537            Seismitoad  Water    Ground    509           5
# 713     647  KeldeoOrdinary Forme  Water  Fighting    580           5
# 714     647  KeldeoResolute Forme  Water  Fighting    580           5
# 726     658              Greninja  Water      Dark    530           6

# %%
# mengambil data pokemon dengan 2 Type, tetapi Type1 Fire
# memiliki attack dan deffense lebih besar dari 80
# tidak termasuk pokemon legendary
# data yang ditampilkan hanya number, name, type1, type2, attack, defense, dan legendary

data_new.query("Type_1 == 'Fire' & Attack >= 80 & Defense >= 80 & Legendary == False ")[[
    'Number', 'Name', 'Type_1', 'Type_2', 'Attack', 'Defense', 'Legendary']]
# Out:
#      Number                       Name Type_1    Type_2  Attack  Defense  \
# 7         6  CharizardMega Charizard X   Fire    Dragon     130      111
# 279     257      BlazikenMega Blaziken   Fire  Fighting     160       80
# 354     323      CameruptMega Camerupt   Fire    Ground     120      100
#
#      Legendary
# 7        False
# 279      False
# 354      False

# %%
# mengambil data pokemon yang termasuk katagori legendary
# memiliki attack dan deffense lebih besar dari 100
# memiliki Total lebih dari sama dengan 600
# data yang ditampilkan hanya number, name, type1, type2, Total, dan legendary

data_new.query("Attack >= 100 & Defense >= 100 & Total >= 600 & Legendary == True ")[[
    'Number', 'Name', 'Type_1', 'Type_2', 'Attack', 'Defense', 'Total', 'Legendary']]
# Out:
#      Number                   Name   Type_1    Type_2  Attack  Defense  Total  \
# 163     150    MewtwoMega Mewtwo X  Psychic  Fighting     190      100    780
# 418     380      LatiasMega Latias   Dragon   Psychic     100      120    700
# 420     381      LatiosMega Latios   Dragon   Psychic     130      100    700
# 424     383  GroudonPrimal Groudon   Ground      Fire     180      160    770
# 426     384  RayquazaMega Rayquaza   Dragon    Flying     180      100    780
# 427     385                Jirachi    Steel   Psychic     100      100    600
# 540     483                 Dialga    Steel    Dragon     120      120    680
# 541     484                 Palkia    Water    Dragon     120      100    680
# 544     487  GiratinaAltered Forme    Ghost    Dragon     100      120    680
# 545     487   GiratinaOrigin Forme    Ghost    Dragon     120      100    680
# 553     494                Victini  Psychic      Fire     100      100    600
# ...

# %% [markdown]
# #### Grouping Data

# %%
# mengetahui pokemon dengan type 1 yang memiliki rataan total lebih dari sama dengan 100

data_new2 = data_new.groupby('Type_1')[['Total']].mean()
data_new2[data_new2['Total'] >= 200]
# Out:
#                Total
# Type_1
# Bug       408.096154
# Dark      450.285714
# Dragon    622.380952
# Electric  490.823529
# Fairy     475.000000
# Fighting  477.857143
# Fire      511.583333
# Flying    390.000000
# Ghost     444.090909
# Grass     436.810811
# Ground    466.421053
# Ice       419.090909
# Normal    390.675676
# Poison    422.076923
# Psychic   498.736842
# Rock      465.142857
# Steel     486.272727
# Water     449.056604

# %%
# mengetahui rataan attack dari setiap pokemon pada type 1

data_new.groupby('Type_1')['Attack'].mean()
# Out:
# Type_1
# Bug          77.711538
# Dark         88.190476
# Dragon      122.571429
# Electric     68.882353
# Fairy        45.000000
# Fighting     95.857143
# Fire         92.166667
# Flying       50.000000
# Ghost        72.545455
# Grass        77.135135
# Ground      101.315789
# Ice          69.090909
# Normal       72.972973
# Poison       77.461538
# Psychic      84.473684
# Rock         90.171429
# Steel        93.318182
# Water        76.735849
# Name: Attack, dtype: float64

# %%
# mengetahui rataan total dari setiap pokemon legendary
# pokemon yang termasuk dalam type 1 fire

data_new[
    (data_new['Type_1']  == 'Fire') &
    (data_new['Legendary'] == True)
].groupby(['Number', 'Name', 'Type_1', 'Legendary'])['Total'].mean()
# Out:
# Number  Name       Type_1  Legendary
# 146     Moltres    Fire    True         580.0
# 250     Ho-oh      Fire    True         680.0
# 485     Heatran    Fire    True         600.0
# 721     Volcanion  Fire    True         600.0
# Name: Total, dtype: float64

# %% [markdown]
# #### Visualisasi Data

# %%
data_new['Legendary'].value_counts()
# Out:
# False    374
# True      40
# Name: Legendary, dtype: int64

# %%
data_new['Legendary'].value_counts().plot(kind = 'bar')
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <AxesSubplot:>

# %%
data_new['Type_1'].value_counts()
# Out:
# Water       53
# Bug         52
# Grass       37
# Normal      37
# Rock        35
# Fire        24
# Steel       22
# Ghost       22
# Dragon      21
# Dark        21
# Ground      19
# Psychic     19
# Electric    17
# Poison      13
# Ice         11
# Fighting     7
# Fairy        2
# Flying       2
# Name: Type_1, dtype: int64

# %%
data_new['Type_1'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
data_new['Generation'].value_counts()
# Out:
# 3    82
# 5    82
# 1    78
# 4    67
# 2    55
# 6    50
# Name: Generation, dtype: int64

# %%
data_new['Generation'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Conclusions, Assumptions, Overall Analysis

# %% [markdown]
# - Jumlah total dari keseluruhan data sebanyak 800 data
# - Terdapat 386 data kosong pada Type_2
# - Beberapa kolom pada tabel dilakukan penamaan ulang seperti # = Number, Type 1 = Type_1, Type 2 = Type_2, Sp. Att = Sp_Att, Sp. Deff = Sp_Deff
# - Terdapat 6 pokemon yang memiliki Type 1 water dan memiliki Type 2, memiliki total lebih besar dari 300, dan termasuk dalam pokemon generastion lebih besar dari 3
# - Terdapat 3 pokemon yang termasuk Type 1 fire dan Type 2, memiliki attack dan defense lebih besar dari 80, dan tidak termasuk pokemon legendary
# - Terdapat pokemon bertype legendary dengan attack dan defense lebih besar dari 100 dan total lebih dari sama dengan 600 sebagai berikut:

# %%
data_new.query("Attack >= 100 & Defense >= 100 & Total >= 600 & Legendary == True ")[[
    'Number', 'Name', 'Type_1', 'Type_2', 'Attack', 'Defense', 'Total', 'Legendary']]
# Out:
#      Number                   Name   Type_1    Type_2  Attack  Defense  Total  \
# 163     150    MewtwoMega Mewtwo X  Psychic  Fighting     190      100    780
# 418     380      LatiasMega Latias   Dragon   Psychic     100      120    700
# 420     381      LatiosMega Latios   Dragon   Psychic     130      100    700
# 424     383  GroudonPrimal Groudon   Ground      Fire     180      160    770
# 426     384  RayquazaMega Rayquaza   Dragon    Flying     180      100    780
# 427     385                Jirachi    Steel   Psychic     100      100    600
# 540     483                 Dialga    Steel    Dragon     120      120    680
# 541     484                 Palkia    Water    Dragon     120      100    680
# 544     487  GiratinaAltered Forme    Ghost    Dragon     100      120    680
# 545     487   GiratinaOrigin Forme    Ghost    Dragon     120      100    680
# 553     494                Victini  Psychic      Fire     100      100    600
# ...

# %% [markdown]
# - Pokemon yang memiliki kedua type tidak termasuk legendary sebanyak 374 dan yang termasuk legendary sebanyak 40, dengan grafik sebagai berikut:

# %%
data_new['Legendary'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# - Pokemon yang memiliki kedua type memiliki beberapa generasi dengan jumlah tertentu yaitu, generasi 1 = 78, generasi 2 = 55, generasi 3 = 82, generasi 4 = 67, generasi 5 = 82, dan generasi 6 = 50, dengan grafik sebagai berikut:

# %%
data_new['Generation'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# - Berikut merupakan data dan grafik dari setiap pokemon bertype 1 yang memiliki type 2 juga:

# %%
data_new['Type_1'].value_counts()
# Out:
# Water       53
# Bug         52
# Grass       37
# Normal      37
# Rock        35
# Fire        24
# Steel       22
# Ghost       22
# Dragon      21
# Dark        21
# Ground      19
# Psychic     19
# Electric    17
# Poison      13
# Ice         11
# Fighting     7
# Fairy        2
# Flying       2
# Name: Type_1, dtype: int64

# %%
data_new['Type_1'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>
